# %%
# !pip install faker
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting faker
#   Downloading Faker-18.4.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.9/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Installing collected packages: faker
# Successfully installed faker-18.4.0

# %%
from faker import Faker

fake = Faker(locale = 'en_US')

# %%
fake = Faker(locale='en_US')
record= fake.simple_profile()
# fake_records= fake.simple_profile()
record['birthdate'] =  str(record['birthdate'])
print(record)
# Out:
# {'username': 'carterjessica', 'name': 'Rebecca Bradford', 'sex': 'F', 'address': 'Unit 1189 Box 9236\nDPO AE 27181', 'mail': 'vasquezjeffrey@hotmail.com', 'birthdate': '1979-06-27'}

# %%
# source: https://github.com/karmus89/blockchain-a-z

import datetime
import hashlib
import json
import sys


class Blockchain:

    def __init__(self):
        
        self.chain = []
        self.create_block(proof=1, previous_hash='0', record = {'username': '', 'name': ' ', 'sex': '', 'address': '', 'mail': '', 'birthdate': ''})

    def create_block(self, proof, previous_hash,record):
        "Create a block."

        block = {
            'index': len(self.chain),
            'timestamp': str(datetime.datetime.now()),
            'proof': proof,
            'previous_hash': previous_hash,
            'record': record

        }
        self.chain.append(block)
        
        return block

    def get_previous_block(self):
        
        return self.chain[-1]

    def hash_proof(self, previous_proof, next_proof):
        "Calculate the SHA256-hash"
        
        return (hashlib
                .sha256(str(next_proof**2 - previous_proof**2).encode())
                .hexdigest())

    def hash_block(self, block):
        "Calculate the SHA256-hash for a block."

        encoded_block = json.dumps(block, sort_keys=True).encode()
        
        return hashlib.sha256(encoded_block).hexdigest()

    def proof_of_work(self, previous_proof):
        "Calculate a new proof related to the previous block."

        next_proof = 1
        check_proof = False

        while check_proof is False:

            if self.hash_proof(previous_proof, next_proof)[:4] == '0000':
                check_proof = True

            else:
                next_proof += 1

        return next_proof

    def is_chain_valid(self, chain):
        "Validate that block and proof hashes are correct across the chain."

        for i in range(len(chain)):

            if i == 0:
                continue

            if chain[i]['previous_hash'] != self.hash_block(chain[i-1]):
                return False

            previous_proof = chain[i-1]['proof']
            next_proof = chain[i]['proof']

            if self.hash_proof(previous_proof, next_proof)[:4] != '0000':
                
                return False

        return True

# %%
import threading
import requests

from flask import Flask, request, jsonify
from werkzeug.serving import run_simple


class BlockchainApp:

    def __init__(self, host='localhost', port=5000, chain=Blockchain):

        self.host = host
        self.port = port
        self.chain = chain()

        self.host_url = f'http://{self.host}:{self.port}'
        
        self.app = Flask(__name__)
        self.add_api_endpoints()
        
        self.thread = threading.Thread(
            target=run_simple,
            kwargs={
                'hostname': self.host,
                'port': self.port,
                'application': self.app}
        )

    def __enter__(self):

        self.start()

        return self

    def __exit__(self, *args):

        self.stop()
        
    def add_api_endpoints(self):
        "Add API endpoints to the Flask WebApp."
        
        self.app.add_url_rule(
            rule='/blocks',
            view_func=self.api_blocks,
            methods=['GET', 'POST']
        )
        self.app.add_url_rule(
            rule='/blocks/validate',
            view_func=self.api_validate,
        )
        self.app.add_url_rule(
            rule='/shutdown',
            view_func=self.api_shutdown,
        )
        self.app.add_url_rule(
            rule='/new_block',
            view_func=self.api_new_block,
            methods=['POST']
        )
    def api_blocks(self):
        "Either retrieve the node's current chain or post a new block to the chain."

        if request.method == 'POST':

            prev_block = self.chain.get_previous_block()
            prev_hash = self.chain.hash_block(prev_block)
            prev_proof = prev_block['proof']

            proof = self.chain.proof_of_work(prev_proof)
            fake = Faker(locale='en_US')
            record= fake.simple_profile()
            # fake_records= fake.simple_profile()
            record['birthdate'] =  str(record['birthdate'])
            block = self.chain.create_block(proof, prev_hash, record)

            response = {'message': 'Congratulations, you just mined a Block!',
                        'block': block}

            return (jsonify(response), 200)

        if request.method == 'GET':

            response = {'chain': self.chain.chain,
                        'length': len(self.chain.chain)}

            return (jsonify(response), 200)

    def api_validate(self):
        "Validate the chain"

        if self.chain.is_chain_valid(self.chain.chain):

            response = {'message': 'Chain is valid.',
                        'valid': True}
            return (jsonify(response), 200)

        else:

            response = {'message': 'Chain is not valid!',
                        'valid': False}
            return (jsonify(response), 500)

    def api_shutdown(self):
        "Shutdown the Flask WebApp"

        # depricated
        # request.environ.get('werkzeug.server.shutdown')()

        return jsonify({'message': 'Shutting down'}), 200

    def start(self):
        "Start the Flask-based Blockchain WebApp."

        self.thread.start()

    def stop(self):
        "Stop the Flask-based Blockchain WebApp."

        if self.thread.is_alive():

            return requests.get(f'{self.host_url}/shutdown')

    def api_new_block(self):
        #it will display the user that there are less than two profiles.
        if len(self.chain.chain) < 3:
            response = {'message': 'There are less than 3 profiles'}
            return (jsonify(response), 500)
        fake = Faker(locale='en_US')
        record= fake.simple_profile()
        record['birthdate'] =  str(record['birthdate'])
        #updating the 3rd block
        blockchain_app.chain.chain[2]['record'] = record
        response = {'message': 'Record of the 3rd profile has been updated with a new profile record.'}

        return (jsonify(response), 200)

# %%
#originalllllllllllllllllllll

import requests
import json
import time

with BlockchainApp() as blockchain_app:

    # wait for server thread ready
    time.sleep(5)

    for _ in range(19):

        response = requests.post(f'{blockchain_app.host_url}/blocks')
        print("Proof={}".format(response.json()['block']['proof']))

    response = requests.get(f'{blockchain_app.host_url}/blocks')
    print("Chain={}".format(json.dumps(response.json(), indent=2)))
    #I am storing the records in dump_of_records, So that I can get male names and Female usernames
    dump_of_records = json.dumps(response.json(), indent=2)

    type(dump_of_records)
    #to access the values of json, if not I am getting the chain and keys
    json.loads(dump_of_records)['chain']
    
    print("Male names from the record:")
    for each in json.loads(dump_of_records)['chain']:
      if each['record']['sex']=='M':
        print (each['record']['name'])
    print()
    print("Female username from the record:")
    for each in json.loads(dump_of_records)['chain']:
      if each['record']['sex']=='F':
        print (each['record']['username'])

    response = requests.get(f'{blockchain_app.host_url}/blocks/validate')
    print(json.dumps(response.json(), indent=2))

    for i in enumerate(blockchain_app.chain.chain):
      print(i)
    response = requests.post(f'{blockchain_app.host_url}/new_block')
    print("Chain={}".format(json.dumps(response.json(), indent=2)))
    # original = blockchain_app.chain.chain[1]['proof']
    # blockchain_app.chain.chain[1]['proof'] = 12345
    # print('Proofs: Original={}, Forged={}'.format(original,blockchain_app.chain.chain[2]['record']))
    # response = requests.post(f'{blockchain_app.host_url}/new_block')
    # print("Chain={}".format(json.dumps(response.json(), indent=2)))

    
    response = requests.get(f'{blockchain_app.host_url}/blocks/validate')
    print(json.dumps(response.json(), indent=2))
    
    # proof_1 = blockchain_app.chain.chain[1]['proof']
    # proof_2 = blockchain_app.chain.chain[2]['proof']

    # forged_hash = blockchain_app.chain.hash_proof(proof_1, proof_2)

    # print("Hashes: \n\tOriginal =\t{}\n\tForged =\t{}".format(blockchain_app.chain.chain[2]['previous_hash'],
    #                                                           forged_hash))
# Out:
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:08] "POST /blocks HTTP/1.1" 200 -
# Proof=533
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:08] "POST /blocks HTTP/1.1" 200 -
# Proof=45293
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:09] "POST /blocks HTTP/1.1" 200 -
# Proof=21391
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:09] "POST /blocks HTTP/1.1" 200 -
# Proof=8018
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:09] "POST /blocks HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:09] "POST /blocks HTTP/1.1" 200 -
# Proof=48191
# Proof=19865
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:10] "POST /blocks HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:10] "POST /blocks HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:10] "POST /blocks HTTP/1.1" 200 -
# Proof=95063
# Proof=15457
# Proof=15479
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:10] "POST /blocks HTTP/1.1" 200 -
# Proof=7889
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:11] "POST /blocks HTTP/1.1" 200 -
# Proof=72474
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:11] "POST /blocks HTTP/1.1" 200 -
# Proof=126616
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:11] "POST /blocks HTTP/1.1" 200 -
# Proof=64161
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:12] "POST /blocks HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:12] "POST /blocks HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:12] "POST /blocks HTTP/1.1" 200 -
# Proof=144125
# Proof=2492
# Proof=22592
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:13] "POST /blocks HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:13] "POST /blocks HTTP/1.1" 200 -
# Proof=107780
# Proof=47346
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:13] "POST /blocks HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:13] "GET /blocks HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:13] "GET /blocks/validate HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:13] "POST /new_block HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:13] "GET /blocks/validate HTTP/1.1" 500 -
# INFO:werkzeug:127.0.0.1 - - [15/Apr/2023 02:28:13] "GET /shutdown HTTP/1.1" 200 -
# Proof=46891
# Chain={
#   "chain": [
#     {
#       "index": 0,
#       "previous_hash": "0",
#       "proof": 1,
#       "record": {
#         "address": "",
#         "birthdate": "",
#         "mail": "",
#         "name": " ",
#         "sex": "",
#         "username": ""
#       },
#       "timestamp": "2023-04-15 02:28:03.154732"
#     },
#     {
#       "index": 1,
#       "previous_hash": "05843e39980e19e18497276fed06a10d761fc315c3ebbc238899f78d5666c1ad",
#       "proof": 533,
#       "record": {
#         "address": "00488 Weiss Passage Suite 397\nSouth Francisco, SC 72650",
#         "birthdate": "1929-08-11",
#         "mail": "robinsonjeffrey@hotmail.com",
#         "name": "David Foster",
#         "sex": "M",
#         "username": "hamiltoncharles"
#       },
#       "timestamp": "2023-04-15 02:28:08.260353"
#     },
#     {
#       "index": 2,
#       "previous_hash": "c82a186d1b2767f4b2cbd021ec9533fe3032a75fa212e2405f536701c35ff800",
#       "proof": 45293,
#       "record": {
#         "address": "068 Michael Stravenue\nTinafurt, MA 52881",
#         "birthdate": "1952-06-19",
#         "mail": "clinesuzanne@hotmail.com",
#         "name": "Amanda Ward",
#         "sex": "F",
#         "username": "angela25"
#       },
#       "timestamp": "2023-04-15 02:28:08.823649"
#     },
#     {
#       "index": 3,
#       "previous_hash": "ae1fa93b9044f7fc2a542bb0fd25640b1643d9962135d9b464ad5baba41dd9e2",
#       "proof": 21391,
#       "record": {
#         "address": "2248 Cannon Pines Apt. 869\nLyonsside, MS 93462",
#         "birthdate": "1936-09-06",
#         "mail": "william04@hotmail.com",
#         "name": "Joseph Johnson",
#         "sex": "M",
#         "username": "sthomas"
#       },
#       "timestamp": "2023-04-15 02:28:09.183614"
#     },
#     {
#       "index": 4,
#       "previous_hash": "e43c01a600b0b4d8c0a0b0b2b83eb89d63b5bc774b266a162548275379faf007",
#       "proof": 8018,
#       "record": {
#         "address": "745 Joseph Villages\nNorth Christopherfort, TN 04985",
#         "birthdate": "1955-05-10",
#         "mail": "sara07@gmail.com",
#         "name": "Dennis White",
#         "sex": "M",
#         "username": "jasonfry"
#       },
#       "timestamp": "2023-04-15 02:28:09.431553"
#     },
#     {
#       "index": 5,
#       "previous_hash": "cdc01f15773b61ef29fce183818a238b508db1270daa3a306ff4b0f987d75b25",
#       "proof": 48191,
#       "record": {
#         "address": "2749 Welch Valleys Apt. 866\nLake Shaunberg, MS 24395",
#         "birthdate": "1966-10-11",
#         "mail": "valerieburch@gmail.com",
#         "name": "Trevor Gonzalez",
#         "sex": "M",
#         "username": "lfrederick"
#       },
#       "timestamp": "2023-04-15 02:28:09.747293"
#     },
#     {
#       "index": 6,
#       "previous_hash": "976a2acce5674159047ec8500c734d50b119c6a52cf6a9aad3bfe4f74b92e84e",
#       "proof": 19865,
#       "record": {
#         "address": "PSC 7761, Box 1339\nAPO AA 35051",
#         "birthdate": "1988-08-01",
#         "mail": "terri08@gmail.com",
#         "name": "Christina Robinson",
#         "sex": "F",
#         "username": "nparker"
#       },
#       "timestamp": "2023-04-15 02:28:09.949529"
#     },
#     {
#       "index": 7,
#       "previous_hash": "af495642a0e7929f59922e92deabb18f1efa765640c7ab6614b2f6838e04faff",
#       "proof": 95063,
#       "record": {
#         "address": "63224 Victoria Ville\nNew Jessicaburgh, OR 66857",
#         "birthdate": "1950-01-12",
#         "mail": "esanders@gmail.com",
#         "name": "Jaime Stevens",
#         "sex": "M",
#         "username": "mjacobs"
#       },
#       "timestamp": "2023-04-15 02:28:10.400140"
#     },
#     {
#       "index": 8,
#       "previous_hash": "91cd51514f4efb591ecf3a7e3880151a4726189b5cdafb441a45316f8c4d9a4a",
#       "proof": 15457,
#       "record": {
#         "address": "444 Travis Ranch Suite 487\nUnderwoodberg, PW 02822",
#         "birthdate": "1936-08-01",
#         "mail": "harrismarc@yahoo.com",
#         "name": "Todd Miller",
#         "sex": "M",
#         "username": "patrickjames"
#       },
#       "timestamp": "2023-04-15 02:28:10.499690"
#     },
#     {
#       "index": 9,
#       "previous_hash": "5787ce24a26a6f0b4370e3e81ae6d5d0100650e78a0b4e9831acad8e8e3f778e",
#       "proof": 15479,
#       "record": {
#         "address": "68094 Hill Extension Apt. 550\nJosephville, SD 80389",
#         "birthdate": "2011-09-02",
#         "mail": "christophermendez@gmail.com",
#         "name": "Lisa Brown",
#         "sex": "F",
#         "username": "kimberlymclaughlin"
#       },
#       "timestamp": "2023-04-15 02:28:10.599164"
#     },
#     {
#       "index": 10,
#       "previous_hash": "12e890ea34999ddcd309181ac5c9ab719526443fe5bbc9b206f018462a96c2e7",
#       "proof": 7889,
#       "record": {
#         "address": "USS Kaiser\nFPO AP 68630",
#         "birthdate": "1963-08-20",
#         "mail": "keithking@hotmail.com",
#         "name": "Marvin Hughes",
#         "sex": "M",
#         "username": "williamsnatalie"
#       },
#       "timestamp": "2023-04-15 02:28:10.735281"
#     },
#     {
#       "index": 11,
#       "previous_hash": "a486f0873ecbe377e9da65e91a7c7f60a64f2ee4ac43a04496e88cec13caa5fa",
#       "proof": 72474,
#       "record": {
#         "address": "08983 Ford Isle\nStephensonton, TN 29737",
#         "birthdate": "1934-01-13",
#         "mail": "markkent@yahoo.com",
#         "name": "Jonathan Thompson",
#         "sex": "M",
#         "username": "stevemay"
#       },
#       "timestamp": "2023-04-15 02:28:11.276644"
#     },
#     {
#       "index": 12,
#       "previous_hash": "be4c039c6903116926c0d760ba4ebc7c29df1ff43d9a84e858c75682cff0b26f",
#       "proof": 126616,
#       "record": {
#         "address": "2713 Freeman Isle Apt. 393\nRachelchester, HI 05697",
#         "birthdate": "1926-01-13",
#         "mail": "achandler@yahoo.com",
#         "name": "Dana Warren",
#         "sex": "F",
#         "username": "orozcodeanna"
#       },
#       "timestamp": "2023-04-15 02:28:11.707020"
#     },
#     {
#       "index": 13,
#       "previous_hash": "ec900c1d007f9902898808a86fe6235a4d69ac17518d043f0a7a4b6c6bc91f54",
#       "proof": 64161,
#       "record": {
#         "address": "206 Sara Cliffs\nMarkside, MO 79663",
#         "birthdate": "1964-09-24",
#         "mail": "karen15@yahoo.com",
#         "name": "Amanda Chung",
#         "sex": "F",
#         "username": "iwilliams"
#       },
#       "timestamp": "2023-04-15 02:28:11.930412"
#     },
#     {
#       "index": 14,
#       "previous_hash": "5dcbe206879e2a17897fa2a1ef96502ebac8623d9a23db85843b496f3b4f49dc",
#       "proof": 144125,
#       "record": {
#         "address": "92135 Lewis Pines\nBakerside, NC 46965",
#         "birthdate": "1917-12-04",
#         "mail": "amywright@hotmail.com",
#         "name": "Mrs. Jasmine Cordova",
#         "sex": "F",
#         "username": "jessicagray"
#       },
#       "timestamp": "2023-04-15 02:28:12.476562"
#     },
#     {
#       "index": 15,
#       "previous_hash": "650d533e33ea3d791413211fb6473a2e8908c1f92ca6aa4bd557ff6512a93048",
#       "proof": 2492,
#       "record": {
#         "address": "5241 Patrick Fork Apt. 178\nWilliamsstad, NC 53130",
#         "birthdate": "1936-04-11",
#         "mail": "shannon79@gmail.com",
#         "name": "Lauren Cantrell",
#         "sex": "F",
#         "username": "michelle71"
#       },
#       "timestamp": "2023-04-15 02:28:12.527377"
#     },
#     {
#       "index": 16,
#       "previous_hash": "ec19971a01da506f9c7586880046a41afe4762fae8cae0d0d736bffbff30855f",
#       "proof": 22592,
#       "record": {
#         "address": "48137 Leonard Wall Apt. 320\nWest Monica, WV 25623",
#         "birthdate": "1989-01-11",
#         "mail": "fjohnson@gmail.com",
#         "name": "Leon Ramos",
#         "sex": "M",
#         "username": "powens"
#       },
#       "timestamp": "2023-04-15 02:28:12.638475"
#     },
#     {
#       "index": 17,
#       "previous_hash": "2d21fced5a2ef7c1014970b38ed80fc143b3562b06def1e8e7360de0eb456bce",
#       "proof": 107780,
#       "record": {
#         "address": "812 Debbie Gardens Apt. 896\nHintonland, NH 04469",
#         "birthdate": "2004-03-27",
#         "mail": "huntvictoria@yahoo.com",
#         "name": "Morgan Watkins",
#         "sex": "F",
#         "username": "sherrykline"
#       },
#       "timestamp": "2023-04-15 02:28:13.005890"
#     },
#     {
#       "index": 18,
#       "previous_hash": "14a9fae5177230cc3222555052f9801c0091e9e0fccc98545fd0e3f8bc5f7ba6",
#       "proof": 47346,
#       "record": {
#         "address": "257 Matthew Point Apt. 398\nPort Christinachester, PA 81327",
#         "birthdate": "2002-01-29",
#         "mail": "taylorsmith@yahoo.com",
#         "name": "Daniel Chambers",
#         "sex": "M",
#         "username": "moorewhitney"
#       },
#       "timestamp": "2023-04-15 02:28:13.171112"
#     },
#     {
#       "index": 19,
#       "previous_hash": "123cf36c3382776bb04acf317c472649f10730d3c342f98e1081c4928958c53b",
#       "proof": 46891,
#       "record": {
#         "address": "76153 Macdonald Cliffs Suite 213\nBrowntown, KS 19746",
#         "birthdate": "1956-04-16",
#         "mail": "mmoore@yahoo.com",
#         "name": "Gerald Hancock",
#         "sex": "M",
#         "username": "darrell96"
#       },
#       "timestamp": "2023-04-15 02:28:13.344648"
#     }
#   ],
#   "length": 20
# }
# Male names from the record:
# David Foster
# Joseph Johnson
# Dennis White
# Trevor Gonzalez
# Jaime Stevens
# Todd Miller
# Marvin Hughes
# Jonathan Thompson
# Leon Ramos
# Daniel Chambers
# Gerald Hancock
#
# Female username from the record:
# angela25
# nparker
# kimberlymclaughlin
# orozcodeanna
# iwilliams
# jessicagray
# michelle71
# sherrykline
# {
#   "message": "Chain is valid.",
#   "valid": true
# }
# (0, {'index': 0, 'timestamp': '2023-04-15 02:28:03.154732', 'proof': 1, 'previous_hash': '0', 'record': {'username': '', 'name': ' ', 'sex': '', 'address': '', 'mail': '', 'birthdate': ''}})
# (1, {'index': 1, 'timestamp': '2023-04-15 02:28:08.260353', 'proof': 533, 'previous_hash': '05843e39980e19e18497276fed06a10d761fc315c3ebbc238899f78d5666c1ad', 'record': {'username': 'hamiltoncharles', 'name': 'David Foster', 'sex': 'M', 'address': '00488 Weiss Passage Suite 397\nSouth Francisco, SC 72650', 'mail': 'robinsonjeffrey@hotmail.com', 'birthdate': '1929-08-11'}})
# (2, {'index': 2, 'timestamp': '2023-04-15 02:28:08.823649', 'proof': 45293, 'previous_hash': 'c82a186d1b2767f4b2cbd021ec9533fe3032a75fa212e2405f536701c35ff800', 'record': {'username': 'angela25', 'name': 'Amanda Ward', 'sex': 'F', 'address': '068 Michael Stravenue\nTinafurt, MA 52881', 'mail': 'clinesuzanne@hotmail.com', 'birthdate': '1952-06-19'}})
# (3, {'index': 3, 'timestamp': '2023-04-15 02:28:09.183614', 'proof': 21391, 'previous_hash': 'ae1fa93b9044f7fc2a542bb0fd25640b1643d9962135d9b464ad5baba41dd9e2', 'record': {'username': 'sthomas', 'name': 'Joseph Johnson', 'sex': 'M', 'address': '2248 Cannon Pines Apt. 869\nLyonsside, MS 93462', 'mail': 'william04@hotmail.com', 'birthdate': '1936-09-06'}})
# (4, {'index': 4, 'timestamp': '2023-04-15 02:28:09.431553', 'proof': 8018, 'previous_hash': 'e43c01a600b0b4d8c0a0b0b2b83eb89d63b5bc774b266a162548275379faf007', 'record': {'username': 'jasonfry', 'name': 'Dennis White', 'sex': 'M', 'address': '745 Joseph Villages\nNorth Christopherfort, TN 04985', 'mail': 'sara07@gmail.com', 'birthdate': '1955-05-10'}})
# (5, {'index': 5, 'timestamp': '2023-04-15 02:28:09.747293', 'proof': 48191, 'previous_hash': 'cdc01f15773b61ef29fce183818a238b508db1270daa3a306ff4b0f987d75b25', 'record': {'username': 'lfrederick', 'name': 'Trevor Gonzalez', 'sex': 'M', 'address': '2749 Welch Valleys Apt. 866\nLake Shaunberg, MS 24395', 'mail': 'valerieburch@gmail.com', 'birthdate': '1966-10-11'}})
# (6, {'index': 6, 'timestamp': '2023-04-15 02:28:09.949529', 'proof': 19865, 'previous_hash': '976a2acce5674159047ec8500c734d50b119c6a52cf6a9aad3bfe4f74b92e84e', 'record': {'username': 'nparker', 'name': 'Christina Robinson', 'sex': 'F', 'address': 'PSC 7761, Box 1339\nAPO AA 35051', 'mail': 'terri08@gmail.com', 'birthdate': '1988-08-01'}})
# (7, {'index': 7, 'timestamp': '2023-04-15 02:28:10.400140', 'proof': 95063, 'previous_hash': 'af495642a0e7929f59922e92deabb18f1efa765640c7ab6614b2f6838e04faff', 'record': {'username': 'mjacobs', 'name': 'Jaime Stevens', 'sex': 'M', 'address': '63224 Victoria Ville\nNew Jessicaburgh, OR 66857', 'mail': 'esanders@gmail.com', 'birthdate': '1950-01-12'}})
# (8, {'index': 8, 'timestamp': '2023-04-15 02:28:10.499690', 'proof': 15457, 'previous_hash': '91cd51514f4efb591ecf3a7e3880151a4726189b5cdafb441a45316f8c4d9a4a', 'record': {'username': 'patrickjames', 'name': 'Todd Miller', 'sex': 'M', 'address': '444 Travis Ranch Suite 487\nUnderwoodberg, PW 02822', 'mail': 'harrismarc@yahoo.com', 'birthdate': '1936-08-01'}})
# (9, {'index': 9, 'timestamp': '2023-04-15 02:28:10.599164', 'proof': 15479, 'previous_hash': '5787ce24a26a6f0b4370e3e81ae6d5d0100650e78a0b4e9831acad8e8e3f778e', 'record': {'username': 'kimberlymclaughlin', 'name': 'Lisa Brown', 'sex': 'F', 'address': '68094 Hill Extension Apt. 550\nJosephville, SD 80389', 'mail': 'christophermendez@gmail.com', 'birthdate': '2011-09-02'}})
# (10, {'index': 10, 'timestamp': '2023-04-15 02:28:10.735281', 'proof': 7889, 'previous_hash': '12e890ea34999ddcd309181ac5c9ab719526443fe5bbc9b206f018462a96c2e7', 'record': {'username': 'williamsnatalie', 'name': 'Marvin Hughes', 'sex': 'M', 'address': 'USS Kaiser\nFPO AP 68630', 'mail': 'keithking@hotmail.com', 'birthdate': '1963-08-20'}})
# (11, {'index': 11, 'timestamp': '2023-04-15 02:28:11.276644', 'proof': 72474, 'previous_hash': 'a486f0873ecbe377e9da65e91a7c7f60a64f2ee4ac43a04496e88cec13caa5fa', 'record': {'username': 'stevemay', 'name': 'Jonathan Thompson', 'sex': 'M', 'address': '08983 Ford Isle\nStephensonton, TN 29737', 'mail': 'markkent@yahoo.com', 'birthdate': '1934-01-13'}})
# (12, {'index': 12, 'timestamp': '2023-04-15 02:28:11.707020', 'proof': 126616, 'previous_hash': 'be4c039c6903116926c0d760ba4ebc7c29df1ff43d9a84e858c75682cff0b26f', 'record': {'username': 'orozcodeanna', 'name': 'Dana Warren', 'sex': 'F', 'address': '2713 Freeman Isle Apt. 393\nRachelchester, HI 05697', 'mail': 'achandler@yahoo.com', 'birthdate': '1926-01-13'}})
# (13, {'index': 13, 'timestamp': '2023-04-15 02:28:11.930412', 'proof': 64161, 'previous_hash': 'ec900c1d007f9902898808a86fe6235a4d69ac17518d043f0a7a4b6c6bc91f54', 'record': {'username': 'iwilliams', 'name': 'Amanda Chung', 'sex': 'F', 'address': '206 Sara Cliffs\nMarkside, MO 79663', 'mail': 'karen15@yahoo.com', 'birthdate': '1964-09-24'}})
# (14, {'index': 14, 'timestamp': '2023-04-15 02:28:12.476562', 'proof': 144125, 'previous_hash': '5dcbe206879e2a17897fa2a1ef96502ebac8623d9a23db85843b496f3b4f49dc', 'record': {'username': 'jessicagray', 'name': 'Mrs. Jasmine Cordova', 'sex': 'F', 'address': '92135 Lewis Pines\nBakerside, NC 46965', 'mail': 'amywright@hotmail.com', 'birthdate': '1917-12-04'}})
# (15, {'index': 15, 'timestamp': '2023-04-15 02:28:12.527377', 'proof': 2492, 'previous_hash': '650d533e33ea3d791413211fb6473a2e8908c1f92ca6aa4bd557ff6512a93048', 'record': {'username': 'michelle71', 'name': 'Lauren Cantrell', 'sex': 'F', 'address': '5241 Patrick Fork Apt. 178\nWilliamsstad, NC 53130', 'mail': 'shannon79@gmail.com', 'birthdate': '1936-04-11'}})
# (16, {'index': 16, 'timestamp': '2023-04-15 02:28:12.638475', 'proof': 22592, 'previous_hash': 'ec19971a01da506f9c7586880046a41afe4762fae8cae0d0d736bffbff30855f', 'record': {'username': 'powens', 'name': 'Leon Ramos', 'sex': 'M', 'address': '48137 Leonard Wall Apt. 320\nWest Monica, WV 25623', 'mail': 'fjohnson@gmail.com', 'birthdate': '1989-01-11'}})
# (17, {'index': 17, 'timestamp': '2023-04-15 02:28:13.005890', 'proof': 107780, 'previous_hash': '2d21fced5a2ef7c1014970b38ed80fc143b3562b06def1e8e7360de0eb456bce', 'record': {'username': 'sherrykline', 'name': 'Morgan Watkins', 'sex': 'F', 'address': '812 Debbie Gardens Apt. 896\nHintonland, NH 04469', 'mail': 'huntvictoria@yahoo.com', 'birthdate': '2004-03-27'}})
# (18, {'index': 18, 'timestamp': '2023-04-15 02:28:13.171112', 'proof': 47346, 'previous_hash': '14a9fae5177230cc3222555052f9801c0091e9e0fccc98545fd0e3f8bc5f7ba6', 'record': {'username': 'moorewhitney', 'name': 'Daniel Chambers', 'sex': 'M', 'address': '257 Matthew Point Apt. 398\nPort Christinachester, PA 81327', 'mail': 'taylorsmith@yahoo.com', 'birthdate': '2002-01-29'}})
# (19, {'index': 19, 'timestamp': '2023-04-15 02:28:13.344648', 'proof': 46891, 'previous_hash': '123cf36c3382776bb04acf317c472649f10730d3c342f98e1081c4928958c53b', 'record': {'username': 'darrell96', 'name': 'Gerald Hancock', 'sex': 'M', 'address': '76153 Macdonald Cliffs Suite 213\nBrowntown, KS 19746', 'mail': 'mmoore@yahoo.com', 'birthdate': '1956-04-16'}})
# Chain={
#   "message": "Record of the 3rd profile has been updated with a new profile record."
# }
# {
#   "message": "Chain is not valid!",
#   "valid": false
# }

# %%
# !apt install net-tools
# !netstat -tulnp | grep :5000
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 24 not upgraded.
# Need to get 196 kB of archives.
# After this operation, 864 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 net-tools amd64 1.60+git20180626.aebd88e-1ubuntu1 [196 kB]
# Fetched 196 kB in 1s (292 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 122349 files and directories currently installed.)
# Preparing to unpack .../net-tools_1.60+git20180626.aebd88e-1ubuntu1_amd64.deb ...
# Unpacking net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Setting up net-tools (1.60+git20180626.aebd88e-1ubuntu1) ...
# Processing triggers for man-db (2.9.1-1) ...
# tcp        0      0 127.0.0.1:5000          0.0.0.0:*               LISTEN      198/python3

# %%
# !kill 2253
# Out:
# /bin/bash: line 0: kill: (2253) - No such process
